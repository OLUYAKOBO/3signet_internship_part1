# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('students_dropout.csv')
df.head(1)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                               0.0
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
cat_cols = []
num_cols = []

for c in df.columns:
    if df[c].dtype == 'object':
        cat_cols.append(c)
    else:
        num_cols.append(c)

# %%
num_cols
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
# ...

# %%
x = df.drop('Target',
           axis = 1)

y = df.Target

# %%
cat_cols
# Out:
# ['Target']

# %%
df[cat_cols].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
df[cat_cols].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Target'>

# %% [markdown]
# ##### There are three target variables, graduate has the highest number of occurences and Enrolled the least.

# %% [markdown]
# ##### 1. Univariate Analysis

# %% [markdown]
# #### Histograms for Numerical variables

# %% [markdown]
# ##### I will be considering only 2 numerical variables

# %% [markdown]
# 1. Admission_grade
# 2. Course

# %%
num_cols = ['Admission grade','Course','Curricular units 1st sem (credited)','Curricular units 1st sem (enrolled)',
            'Curricular units 1st sem (evaluations)',
            'Curricular units 1st sem (approved)',
            'Curricular units 1st sem (grade)',
            'Curricular units 1st sem (without evaluations)',
            'Curricular units 2nd sem (credited)',
            'Curricular units 2nd sem (enrolled)',
            'Curricular units 2nd sem (evaluations)',
            'Curricular units 2nd sem (approved)',
            'Curricular units 2nd sem (grade)',
            'Curricular units 2nd sem (without evaluations)']

# %%
num_cols
# Out:
# ['Admission grade',
#  'Course',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)']

# %%
# Loop through each categorical column and create a bar plot
for c in num_cols:
    plt.figure(figsize=(8, 4))  # Set the figure size
    df[c].hist()
    plt.title(f'Histogram of {c}')  # Add a title to each plot
    #sns.boxplot(df[c])
    plt.xlabel(c)  # Label the x-axis with the column name
    plt.ylabel('Count')  # Label the y-axis as 'Count'
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if necessary
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a light grid to the y-axis
    plt.show()  # Display the plot

# %% [markdown]
# ##### The charts above are the histograms of the numerical features

# %%
# Loop through each categorical column and create a bar plot
for c in num_cols:
    plt.figure(figsize=(8, 4))  # Set the figure size
    #df[c].hist()
    plt.title(f'Boxplot of {c}')  # Add a title to each plot
    sns.boxplot(df[c])
    plt.xlabel(c)  # Label the x-axis with the column name
    plt.ylabel('Count')  # Label the y-axis as 'Count'
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if necessary
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a light grid to the y-axis
    plt.show()  # Display the plot

# %% [markdown]
# ###### The chart above represents the boxplot of the numerical features

# %% [markdown]
# ##### Bar Charts for Categorical values

# %% [markdown]
# The categorical features under consideration are;
# 1. Target
# 2. Marital status
# 3. Gender
# 4. Scholarship holder
# 5. International
# 6. Displaced
# 7. Debtor

# %%
cat_cols = ['Target','Marital status','Gender','Scholarship holder',
           'International','Displaced','Debtor']



# Loop through each categorical column and create a bar plot
for c in cat_cols:
    plt.figure(figsize=(8, 4))  # Set the figure size
    df[c].value_counts().plot.bar(color='skyblue')  # Create a bar plot with a custom color
    plt.title(f'Distribution of {c}')  # Add a title to each plot
    plt.xlabel(c)  # Label the x-axis with the column name
    plt.ylabel('Count')  # Label the y-axis as 'Count'
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if necessary
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a light grid to the y-axis
    plt.show()  # Display the plot

# %% [markdown]
# ###### The distribution of the categorical features is shown above

# %% [markdown]
# ###### Descriptive Statistics

# %%
df.describe().T
# Out:
#                                                  count         mean  \
# Marital status                                  4424.0     1.178571
# Application mode                                4424.0    18.669078
# Application order                               4424.0     1.727848
# Course                                          4424.0  8856.642631
# Daytime/evening attendance\t                    4424.0     0.890823
# Previous qualification                          4424.0     4.577758
# Previous qualification (grade)                  4424.0   132.613314
# Nacionality                                     4424.0     1.873192
# Mother's qualification                          4424.0    19.561935
# Father's qualification                          4424.0    22.275316
# Mother's occupation                             4424.0    10.960895
# Father's occupation                             4424.0    11.032324
# Admission grade                                 4424.0   126.978119
# ...

# %% [markdown]
# This shows the descriptive statistics of the data, the mean, median and standard deviations

# %% [markdown]
# #### 2. Bivariate Analysis

# %% [markdown]
# ##### Scatter plots of numerical features

# %%
num_cols
# Out:
# ['Admission grade',
#  'Course',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)']

# %%
plt.scatter(df['Admission grade'],df['Course'])
plt.xlabel('Admission grade')
plt.ylabel('Course')
plt.title('Course vs Admission Grade')
plt.show()

# %%
plt.scatter(df['Curricular units 1st sem (approved)'],df['Curricular units 1st sem (grade)'])
plt.xlabel('Curricular units 1st sem (approved)')
plt.ylabel('Curricular units 1st sem (grade)')
plt.title('1st sem grade vs approved')
plt.show()

# %%
plt.scatter(df['Curricular units 1st sem (enrolled)'],df['Curricular units 1st sem (approved)'])
plt.xlabel('Curricular units 1st sem (enrolled)')
plt.ylabel('Curricular units 1st sem (approved)')
plt.title('1st sem approved vs enrolled')
plt.show()

# %%
plt.scatter(df['Curricular units 2nd sem (approved)'],df['Curricular units 2nd sem (grade)'])
plt.xlabel('Curricular units 2nd sem (approved)')
plt.ylabel('Curricular units 2nd sem (grade)')
plt.title('2nd sem grade vs approved')
plt.show()

# %% [markdown]
# The scatter plots are displayed above

# %%
df.drop('Target',
       axis =1,
       inplace=True)

# %% [markdown]
# #### Correlation Plot

# %%
def corr():
    # Calculate the correlation matrix
    corr_matrix = df.corr()

    # Plot the heatmap
    plt.figure(figsize=(40, 40))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=2)

    plt.title('Correlation Matrix Heatmap')
    plt.show()
corr()
# Out:
# C:\Users\Public\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\Public\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Chi Square test

# %%
cat_cols
# Out:
# ['Target',
#  'Marital status',
#  'Gender',
#  'Scholarship holder',
#  'International',
#  'Displaced',
#  'Debtor']

# %%
contingency_table = pd.crosstab(df['Gender'], df['Marital status'])
print(contingency_table)
# Out:
# Marital status     1    2  3   4   5  6
# Gender
# 0               2552  221  3  69  18  5
# 1               1367  158  1  22   7  1

# %%
import scipy.stats as stats

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-square Statistic: 13.676374138233017
# P-value: 0.01780122369437003
# Degrees of Freedom: 5
# Expected Frequencies:
# [[2.54061754e+03 2.45698915e+02 2.59312839e+00 5.89936709e+01
#   1.62070524e+01 3.88969259e+00]
#  [1.37838246e+03 1.33301085e+02 1.40687161e+00 3.20063291e+01
#   8.79294756e+00 2.11030741e+00]]

# %% [markdown]
# #### 3. Multivariate Analysis

# %%
df = df[['Course','Marital status','Debtor','International']]

# %%
df
# Out:
#       Course  Marital status  Debtor  International
# 0        171               1       0              0
# 1       9254               1       0              0
# 2       9070               1       0              0
# 3       9773               1       0              0
# 4       8014               2       0              0
# ...      ...             ...     ...            ...
# 4419    9773               1       0              0
# 4420    9773               1       1              1
# 4421    9500               1       0              0
# 4422    9147               1       0              0
# 4423    9773               1       0              1
#
# [4424 rows x 4 columns]

# %% [markdown]
# ##### Pairplot of selected features

# %%
sns.pairplot(df,hue = 'Debtor')
# Out:
# C:\Users\Public\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ##### Principal component analysis
# * In this section I am going to perform pca on the data to extract 10 features that best explain the dataset.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_standardized = scaler.fit_transform(x)

pca = PCA(n_components=10)  # Number of components you want to keep
principal_components = pca.fit_transform(df_standardized)

# Step 4: Create a DataFrame with principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2','PC3','PC4','PC5',
                                                         'PC6','PC7','PC8','PC9','PC10'])

# Step 5: Explained variance ratio
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.17666395 0.0988699  0.05862559 0.05585338 0.05259359 0.04674366
#  0.04426997 0.04268044 0.03588182 0.03435778]

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.6465400830398733

# %% [markdown]
# The sum of explained variance means that 65% of the info of the data is explained by the PCA

# %%
# !pip install plotly
